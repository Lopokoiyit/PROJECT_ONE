# %%
# %matplotlib notebook
import pandas as pd
import requests
import matplotlib.pyplot as plt
import numpy as np
import json 


url = requests.get = "https://covid19.pillious.now.sh/api/data"
data = response.json()

# Use json.dumps to print the json
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "cases": 583653,
#         "daysSinceLastCase": 0,
#         "deaths": 11677,
#         "name": "South Africa",
#         "newCases": 4513,
#         "newDeaths": 121,
#         "region": "African Region",
#         "reportDate": "2020-08-16T00:00:00.000Z",
#         "reportNumber": 209,
#         "territory": false,
#         "transmissionType": 0
#     },
#     {
#         "cases": 48770,
#         "daysSinceLastCase": 0,
#         "deaths": 974,
#         "name": "Nigeria",
#         "newCases": 325,
#         "newDeaths": 1,
#         "region": "African Region",
#         "reportDate": "2020-08-16T00:00:00.000Z",
#         "reportNumber": 209,
#         "territory": false,
#         "transmissionType": 0
#     },
#     {
#         "cases": 28894,
#         "daysSinceLastCase": 0,
#         "deaths": 509,
#         "name": "Ethiopia",
#         "newCases": 1652,
#         "newDeaths": 17,
#         "region": "African Region",
# ...

# %%
response.status_code
# Out:
# 200
